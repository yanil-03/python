# %%
# Pandas ---> it is an open source library of python tht is used to handle
# data manipulations

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# Data structure of pandas
# a. Series ---> it is one dimensional array and it shows only values
# b. DataFrame ---> it is two dimensional array and it shows values in rows
# and columns

# %%
a = pd.Series([1,45,78,90])
a
# Out:
# 0     1
# 1    45
# 2    78
# 3    90
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a = {
    'Emp_id' : [1,2,3,4,5],
    'Name' : ["Sam", "Rahul", "Mohit", "Aniket", "pallavi"],
    'Dept' : ["HR", "IT", "HR", "IT", "HR"],
    'Salary' : [10000, 20000, 30000, 40000, 50000]
 }

print(a)
# Out:
# {'Emp_id': [1, 2, 3, 4, 5], 'Name': ['Sam', 'Rahul', 'Mohit', 'Aniket', 'pallavi'], 'Dept': ['HR', 'IT', 'HR', 'IT', 'HR'], 'Salary': [10000, 20000, 30000, 40000, 50000]}

# %%
df = pd.DataFrame(a)
df
# Out:
#    Emp_id     Name Dept  Salary
# 0       1      Sam   HR   10000
# 1       2    Rahul   IT   20000
# 2       3    Mohit   HR   30000
# 3       4   Aniket   IT   40000
# 4       5  pallavi   HR   50000

# %%
df.to_csv('/content/employee.csv',index=False)

# %%
df1 = pd.read_csv('/content/covid_toy.csv')
df1
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df2 = pd.read_csv('/content/placement.csv')
df2
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df3 = pd.read_csv('/content/tips.csv')
df3
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df4 = pd.read_csv('/content/titanic.csv')
df4
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df2     #placement dataset
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
# top 5 data
df2.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
# bottom 5
df2.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
# return statistically view of data

df2.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
# data type information
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df2
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
topLeftcorner = df2.iloc[ :4, :3]  #iloc[row_range, columne_range]
topLeftcorner
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df2.loc[1:3, [ 'cgpa', 'placed']]  #iloc[row_range, columne_name]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
df1
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [90 rows x 6 columns]

# %%
p = df1.dtypes
p
# Out:
# age            int64
# gender        object
# fever        float64
# cough         object
# city          object
# has_covid     object
# dtype: object

# %%
b = df1.empty ###returns true if there is missing data in data frame otherwise return false
b
# Out:
# False

# %%
df1.isnull().sum()  ### for checking missing values
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
 df1 = df1.dropna() ### for removing missing values

# %%
i = df1.ndim  ### returns dimension of data frame
i
# Out:
# 2

# %%
df = pd.read_csv('/content/flipkart.csv')
df
# Out:
#                                                model  ratings          count  \
# 0         SAMSUNG Galaxy S24 5G (Onyx Black, 512 GB)      4.5  1,813 Ratings
# 1       SAMSUNG Galaxy S24 5G (Amber Yellow, 512 GB)      4.5  1,813 Ratings
# 2                  realme GT 6 (Razor Green, 256 GB)      4.5  1,051 Ratings
# 3      SAMSUNG Galaxy A36 5G (Awesome Black, 128 GB)      4.4    279 Ratings
# 4         SAMSUNG Galaxy S24 5G (Onyx Black, 256 GB)      4.5  1,813 Ratings
# 5        SAMSUNG Galaxy S24 5G (Marble Gray, 128 GB)      4.5  1,813 Ratings
# 6                vivo T3 Ultra (Frost Green, 256 GB)      4.5  7,420 Ratings
# 7              IQOO Neo 10R 5G (Raging Blue, 256 GB)      4.5     25 Ratings
# 8   SAMSUNG Galaxy A36 5G (Awesome Lavender, 256 GB)      4.4    279 Ratings
# 9            SAMSUNG Galaxy S24 FE 5G (Blue, 128 GB)      4.4  1,747 Ratings
# 10           SAMSUNG Galaxy S24 FE 5G (Mint, 128 GB)      4.4  1,747 Ratings
# ...

# %%
df = pd.read_csv('/content/placement.csv')
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000
