# %%
# Exception handling
# 1. try block ---> code pass who can execute
# 2. Exception ---> message pass when we show error in our existing code

# %%
try:
  a = 5
  b = a/2
  print(b)
  b = a/0
  print(b)
except Exception as e:
  print("please check your value",e)
# Out:
# 2.5
# please check your value division by zero

# %%
def exception_handling():
  try:
    result = 10/0
    print(result)
  except ZeroDivisionError as e:
    print("you cannot divide by zero",e)
exception_handling()
# Out:
# you cannot divide by zero division by zero

# %%
def exception_handling():
  try:
    number = int(input("enter a number:"))
    print(number)
  except ValueError as e:
    print("you cannot enter characters only pass integers",e)
exception_handling()
# Out:
# enter a numbersam
# you cannot enter characters only pass integers invalid literal for int() with base 10: 'sam'

# %%
def exception_handling():
  try:
    list_data = [1,2,3]
    print(list_data[2])
    print(list_data[6])
  except IndexError as e:
    print("Index error",e)
exception_handling()
# Out:
# 3
# Index error list index out of range

# %%
def exception_handling():
  try:
    data = {"name":"ram"}
    print(data["name"])
    print(data["subject"])
  except KeyError as e:
    print("Caught key Error",e)
exception_handling()
# Out:
# ram
# Caught key Error 'subject'

# %%
def exception_handling():
  try:
    number = int(input("enter a number:"))
    result = 10/number
    print(result)
  except ZeroDivisionError as e:
    print("You cannot divide by 0")
  except ValueError as e:
    print("You cannot enter characters")

exception_handling()
# Out:
# enter a number:sam
# You cannot enter characters

# %%
# Out:
# 20

# %%
import random
words = ['python', 'coding', 'game', 'computer']
word = random.choice(words)
word_letters = set(word)  # Letters in the word
guessed_letters = set()
lives = 6
while len(word_letters) > 0 and lives > 0:
    print('You have', lives, 'lives left. Guessed letters:', ' '.join(guessed_letters))
    word_list = [letter if letter in guessed_letters else '_' for letter in word]
    print('Word:', ' '.join(word_list))
    guess = input("Guess a letter: ").lower()
    if guess in word_letters:
        guessed_letters.add(guess)
        word_letters.remove(guess)
    else:
        lives -= 1
        print("Wrong guess!")
if lives == 0:
    print("Sorry, you lost! The word was", word)
else:
    print("Congrats! You guessed the word", word)
# Out:
# You have 6 lives left. Guessed letters:
# Word: _ _ _ _ _ _
# Guess a letter: t
# Wrong guess!
# You have 5 lives left. Guessed letters:
# Word: _ _ _ _ _ _
# Guess a letter: p
# Wrong guess!
# You have 4 lives left. Guessed letters:
# Word: _ _ _ _ _ _
# Guess a letter: c
# You have 4 lives left. Guessed letters: c
# Word: c _ _ _ _ _
# Guess a letter: ode
# Wrong guess!
# You have 3 lives left. Guessed letters: c
# Word: c _ _ _ _ _
# Guess a letter: o
# You have 3 lives left. Guessed letters: c o
# Word: c o _ _ _ _
# Guess a letter: d
# You have 3 lives left. Guessed letters: d c o
# Word: c o d _ _ _
# Guess a letter: e
# Wrong guess!
# You have 2 lives left. Guessed letters: d c o
# Word: c o d _ _ _
# Guess a letter: e
# Wrong guess!
# You have 1 lives left. Guessed letters: d c o
# Word: c o d _ _ _
# Guess a letter: i
# You have 1 lives left. Guessed letters: d c o i
# Word: c o d i _ _
# Guess a letter: n
# You have 1 lives left. Guessed letters: n c d i o
# ...

# %%
expenses = []
def add_expense(date, category, amount):
    expenses.append({'date': date, 'category': category, 'amount': amount})
def show_total():
    total = sum(expense['amount'] for expense in expenses)
    print(f"Total Expense: {total}")
while True:
    choice = input("1. Add Expense\n2. Show Total\n3. Exit\nEnter choice: ")
    if choice == '1':
        date = input("Enter date (YYYY-MM-DD): ")
        category = input("Enter category: ")
        amount = float(input("Enter amount: "))
        add_expense(date, category, amount)
    elif choice == '2':
        show_total()
    elif choice == '3':
        break
