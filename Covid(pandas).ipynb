# %%
import pandas as pd

# %%
df = pd.read_csv('/content/covid_toy.csv')
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df.tail(2)
# Out:
#     age  gender  fever   cough     city has_covid
# 98    5  Female   98.0  Strong   Mumbai        No
# 99   10  Female   98.0  Strong  Kolkata       Yes

# %%
df.shape
# Out:
# (100, 6)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')

# %%
df.dtypes
# Out:
# age            int64
# gender        object
# fever        float64
# cough         object
# city          object
# has_covid     object
# dtype: object

# %%
df.describe()
# Out:
#               age       fever
# count  100.000000   90.000000
# mean    44.220000  100.844444
# std     24.878931    2.054926
# min      5.000000   98.000000
# 25%     20.000000   99.000000
# 50%     45.000000  101.000000
# 75%     66.500000  102.750000
# max     84.000000  104.000000

# %%
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df['gender'].value_counts()
###value_count() will return total frequency of each subcategory in a column
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df['has_covid'].value_counts()
# Out:
# has_covid
# No     55
# Yes    45
# Name: count, dtype: int64

# %%
##dataframe is mutable
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df['gender'][0] = 'Female'
df.head(3)
# Out:
# <ipython-input-15-3766666818>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['gender'][0] = 'Female'
# <ipython-input-15-3766666818>:1: SettingWithCopyWarning:
# ...

# %%
df2 = df.copy()

# %%
df2['gender'] = df2['gender'].map({'Male':1,'Female':0})
df2.head(3)
# Out:
#    age  gender  fever cough     city has_covid
# 0   60       0  103.0  Mild  Kolkata        No
# 1   27       1  100.0  Mild    Delhi       Yes
# 2   42       1  101.0  Mild    Delhi        No

# %%
df2['Gender'] = df2['gender'].map({'Male':1,'Female':0})
df2
# Out:
#     age  gender  fever   cough       city has_covid  Gender
# 0    60       0  103.0    Mild    Kolkata        No     NaN
# 1    27       1  100.0    Mild      Delhi       Yes     NaN
# 2    42       1  101.0    Mild      Delhi        No     NaN
# 3    31       0   98.0    Mild    Kolkata        No     NaN
# 4    65       0  101.0    Mild     Mumbai        No     NaN
# ..  ...     ...    ...     ...        ...       ...     ...
# 95   12       0  104.0    Mild  Bangalore        No     NaN
# 96   51       0  101.0  Strong    Kolkata       Yes     NaN
# 97   20       0  101.0    Mild  Bangalore        No     NaN
# 98    5       0   98.0  Strong     Mumbai        No     NaN
# 99   10       0   98.0  Strong    Kolkata       Yes     NaN
#
# [100 rows x 7 columns]

# %%
df2 = df2.drop(columns=['Gender', 'cough','city','has_covid'])
df2
# Out:
#     age  gender  fever
# 0    60       0  103.0
# 1    27       1  100.0
# 2    42       1  101.0
# 3    31       0   98.0
# 4    65       0  101.0
# ..  ...     ...    ...
# 95   12       0  104.0
# 96   51       0  101.0
# 97   20       0  101.0
# 98    5       0   98.0
# 99   10       0   98.0
#
# [100 rows x 3 columns]

# %%
# df2['city'].value_counts()

# %%
df2 = df.copy()
df2['city'] = df2['city'].map({'Kolkata':1,'Bangalore':0, 'Delhi':2,'Mumbai':3})
df2['cough'] = df2['cough'].map({'Mild':1,'Strong':0})
df2['has_covid'] = df2['has_covid'].map({'Yes':1,'No':0})
df2
# Out:
#     age  gender  fever  cough  city  has_covid
# 0    60  Female  103.0      1     1          0
# 1    27    Male  100.0      1     2          1
# 2    42    Male  101.0      1     2          0
# 3    31  Female   98.0      1     1          0
# 4    65  Female  101.0      1     3          0
# ..  ...     ...    ...    ...   ...        ...
# 95   12  Female  104.0      1     0          0
# 96   51  Female  101.0      0     1          1
# 97   20  Female  101.0      1     0          0
# 98    5  Female   98.0      0     3          0
# 99   10  Female   98.0      0     1          1
#
# [100 rows x 6 columns]

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60  Female  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.isnull().sum()   #to check the number of empty entries
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df['fever'] = df['fever'].fillna(100)
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60  Female  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df['fever'].mean()
# Out:
# np.float64(100.76)

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
df['fever'].mean()
# Out:
# np.float64(100.76)

# %%
# Loc And Iloc

# df.loc[row_range , column_name]  ---> Last index value will be include .
# df.iloc[row_range , column_range] ---> Last index value will not be include .

# %%
df.loc[2:5, ['age','gender','has_covid']]
# Out:
#    age  gender has_covid
# 2   42    Male        No
# 3   31  Female        No
# 4   65  Female        No
# 5   84  Female       Yes

# %%
df.iloc[2:5, 0:4]
# Out:
#    age  gender  fever cough
# 2   42    Male  101.0  Mild
# 3   31  Female   98.0  Mild
# 4   65  Female  101.0  Mild

# %%
df2 = df.copy()

# %%
df2.loc[2:5 , ['age' , 'fever']] = 900
df2.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60  Female  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2  900    Male  900.0  Mild    Delhi        No
# 3  900  Female  900.0  Mild  Kolkata        No
# 4  900  Female  900.0  Mild   Mumbai        No

# %%
df = df.rename(columns = {
    "fever" :  "Latest_updated_fever",
    'age':'Updated_Age'})
df.head()
# Out:
#    Updated_Age  gender  Latest_updated_fever cough     city has_covid
# 0           60  Female                 103.0  Mild  Kolkata        No
# 1           27    Male                 100.0  Mild    Delhi       Yes
# 2           42    Male                 101.0  Mild    Delhi        No
# 3           31  Female                  98.0  Mild  Kolkata        No
# 4           65  Female                 101.0  Mild   Mumbai        No

# %%
# filtered dataFrame creation

df = df[['Updated_Age' , 'Latest_updated_fever' , 'has_covid']]
df.head()
# Out:
#    Updated_Age  Latest_updated_fever has_covid
# 0           60                 103.0        No
# 1           27                 100.0       Yes
# 2           42                 101.0        No
# 3           31                  98.0        No
# 4           65                 101.0        No

# %%
df3 = df2.loc[2:5, ['age','gender','has_covid']]
df3.head()
# Out:
#    age  gender has_covid
# 2  900    Male        No
# 3  900  Female        No
# 4  900  Female        No
# 5  900  Female       Yes
