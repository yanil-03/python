# %%
# 1. Check if a number is positive, negative, or zero
# Write a Python program that takes a number as input and checks whether it is positive, negative, or zero.

num = int(input("Enter a number:"))

if(num>0):
  print(num," is positive")

elif(num<0):
  print(num," is negative")

else:
  print(num," is zero")
# Out:
# Enter a number:3
# 3 Number is positive

# %%
# 2. Check if a number is even or odd
# Write a Python program that asks the user to enter a number and determines if it is even or odd.
num = int(input("Enter a number:"))

if(num%2==0):
  print(num," is Even")

else:
  print(num," is Odd")
# Out:
# Enter a number:2
# 2  is Even

# %%
# 3. Find the largest of two numbers
# Write a Python program that takes two numbers as input and prints the largest one.
num1 = int(input("Enter num1:"))
num2 = int(input("Enter num2:"))

if(num1>num2):
  print(num1," is Greater")

elif(num1==num2):
  print(num1,num2,"are Equal")

else:
  print(num2," is Greater")
# Out:
# Enter num1:21
# Enter num2:32
# 32  is Greater

# %%
# 4. Find the largest of three numbers
# Write a Python program that takes three numbers as input and determines the largest of the three.

num1 = int(input("Enter num1:"))   #23
num2 = int(input("Enter num2:"))  #32
num3 = int(input("Enter num3:"))  #54

if(num1 > num2):

 if(num1 > num3):
  print(num1,"is Greater")

elif(num2>num3):
  print(num2," is Greater")

else:
  print(num3," is Greater")
# Out:
# Enter num1:23
# Enter num2:32
# Enter num3:12
# 32  is Greater

# %%
# 5. Check if a year is a leap year
# Write a Python program that takes a year as input and checks whether it is a leap year or not.
year = int(input("Enter the year:"))

if(year%4==0):
  print(year,"is the leap year!!!")

else:
  print(year,"is not the leap year!!!")
# Out:
# Enter the year:2016
# 2016 is the leap year!!!

# %%
# 6. Grade a student based on marks
# Write a Python program that asks the user to enter their marks and assigns a grade based on the following:

# 90-100: A
# 80-89: B
# 70-79: C
# 60-69: D
# Below 60: Fail

marks = int(input("Enter your marks:"))

if(100>=marks>=90):
  print("Grade A")

elif(89>=marks>=80):
  print("Grade B")

elif(79>=marks>=70):
  print("Grade C")

elif(69>=marks>=60):
  print("Grade D")

elif(60 > marks >= 0):
  print("Fail ! ! !")

else:
  print("Invalid marks ! ! !")
# Out:
# Enter your marks:87
# Grade B

# %%
# 7. Check if a number is divisible by both 5 and 11
# Write a Python program that takes a number as input and checks if it is divisible by both 5 and 11.

num = int(input("Enter a number: "))

if(num%5==0 and num%11==0):
  print("it is divisible by both 5 and 11.")

else:
  print("it is not divisible by both 5 and 11.")
# Out:
# Enter a number: 110
# it is divisible by both 5 and 11.

# %%
# 8. Check if a character is a vowel or consonant
# Write a Python program that takes a single character as input and checks whether it is a vowel (a, e, i, o, u) or a consonant.

ch = input("Enter a number: ")

if(ch == 'a' or ch == 'e' or ch == 'i' or ch == 'o' or ch == 'u'):
  print("it is vowel.")

else:
  print("it is consonent.")
# Out:
# Enter a number: i
# it is vowel.

# %%
# 9. Check if a number is within a specific range
# Write a Python program that checks whether a given number lies between 10 and 50 (inclusive).

num = int(input("Enter a number: "))

if(10<num<50):
  print("Number is in the range.")

else:
  print("Number is not in the range.")
# Out:
# Enter a number: 67
# Number is not in the range.

# %%
# 10. Check if a person is eligible to vote
# Write a Python program that asks for a person's age and checks if they are eligible to vote (age ≥ 18).
age = int(input("Enter your age: "))

if(age >= 18):
  print("Eligible to vote!!!")

else:
  print("Not eligible to vote!!!")
# Out:
# Enter your age: 23
# Eligible to vote!!!

# %%
# total seats=100  1 seat fare 100
num =int(input("Enter number of seats for booking: "))

total = 100

if(0 < num <= total):
  print("Your total fare :",num*100)

  total=total-num

  print("Available seats :",total)

else:
  print("Unavailable! Only",total,"seats are available.")
# Out:
# Enter number of seats for booking: 111
# Unavailable! Only 100 seats are available.
