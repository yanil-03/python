# %%
import pandas as pd

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
a = df.iloc[:4 , :3]
a
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
a = df.loc [ 1:3, ['cgpa' , 'placed'] ]
a
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
b = df.empty
b
# Out:
# False

# %%
a = df.isnull().sum()
a
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
t = df.size   #row count * columne count
t
# Out:
# 300

# %%
d = df.shape  #shape = n(rows) , n(column)
d
# Out:
# (100, 3)

# %%
s = df.values   #get a numpy
s
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df = df.copy()

# %%
p = df.sort_values(by=['resume_score'])
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
r = df.sort_index()
r
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df['cgpa'] = df['cgpa'].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
df['resume_score'] = df['resume_score'].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
df['cgpa'] = df['cgpa'].add(4)
df['resume_score'] = df['resume_score'].add(5)
df['placed'] = df['placed'].add(6)
df
# Out:
#     cgpa  resume_score  placed
# 0     16            11       7
# 1     14            10       6
# 2     16            13       7
# 3     14            12       7
# 4     15            12       7
# ..   ...           ...     ...
# 95    14            11       6
# 96    16            12       7
# 97    14            12       6
# 98    16            10       7
# 99    14            11       6
#
# [100 rows x 3 columns]

# %%
s = df.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
p = df.max()
p
# Out:
# cgpa            17
# resume_score    14
# placed           7
# dtype: int64

# %%
q = df.min()
q
# Out:
# cgpa            13
# resume_score     9
# placed           6
# dtype: int64

# %%
r = df['cgpa'].mean()
r
# Out:
# np.float64(14.47)

# %%
s = df['cgpa'].median()
s
# Out:
# 14.0

# %%
w = df.mean()
w
# Out:
# cgpa            14.47
# resume_score    11.47
# placed           6.50
# dtype: float64

# %%
w = df.median()
w
# Out:
# cgpa            14.0
# resume_score    12.0
# placed           6.5
# dtype: float64

# %%
g = df.filter(items = ['cgpa' , 'placed'])
g

df[['cgpa', 'placed']]
# Out:
#     cgpa  placed
# 0     16       7
# 1     14       6
# 2     16       7
# 3     14       7
# 4     15       7
# ..   ...     ...
# 95    14       6
# 96    16       7
# 97    14       6
# 98    16       7
# 99    14       6
#
# [100 rows x 2 columns]

# %%
s = df.filter(items = [5,6], axis = 0)  ###axis = 0 means row wise operations
s
# Out:
#    cgpa  resume_score  placed
# 5    16            11       7
# 6    13            12       6

# %%
t = df.filter(like = '5', axis = 0)
t
# Out:
#     cgpa  resume_score  placed
# 5     16            11       7
# 15    16            10       7
# 25    15            10       7
# 35    16            12       7
# 45    16            10       7
# 50    16            11       7
# 51    14            12       6
# 52    13            12       6
# 53    14            12       6
# 54    13            12       6
# 55    14            11       7
# 56    14            11       6
# 57    14            12       6
# 58    14            12       6
# 59    13            12       6
# 65    14            13       6
# 75    14            12       7
# 85    14            10       6
# 95    14            11       6

# %%
s = df.to_dict()      #save in dictionary
s
# Out:
# {'cgpa': {0: 16,
#   1: 14,
#   2: 16,
#   3: 14,
#   4: 15,
#   5: 16,
#   6: 13,
#   7: 14,
#   8: 14,
#   9: 15,
#   10: 14,
#   11: 13,
#   12: 14,
#   13: 16,
#   14: 15,
#   15: 16,
#   16: 16,
#   17: 15,
#   18: 13,
#   19: 14,
#   20: 13,
#   21: 14,
#   22: 14,
#   23: 14,
#   24: 16,
#   25: 15,
#   26: 14,
#   27: 13,
#   28: 15,
#   29: 14,
#   30: 15,
#   31: 13,
#   32: 13,
#   33: 16,
#   34: 16,
#   35: 16,
#   36: 16,
#   37: 17,
#   38: 14,
#   39: 15,
#   40: 16,
#   41: 16,
#   42: 14,
#   43: 16,
#   44: 13,
#   45: 16,
#   46: 13,
#   47: 15,
#   48: 13,
#   49: 13,
#   50: 16,
#   51: 14,
#   52: 13,
#   53: 14,
#   54: 13,
#   55: 14,
#   56: 14,
#   57: 14,
#   58: 14,
#   59: 13,
#   60: 13,
#   61: 14,
#   62: 13,
#   63: 16,
#   64: 15,
#   65: 14,
#   66: 16,
#   67: 14,
#   68: 14,
#   69: 16,
#   70: 15,
#   71: 15,
#   72: 15,
#   73: 13,
#   74: 13,
#   75: 14,
#   76: 17,
#   77: 13,
#   78: 13,
#   79: 13,
#   80: 15,
#   81: 14,
#   82: 15,
# ...

# %%
q = df.to_string()      # save in string
# q

# %%
e = df.to_csv("path_location")

# %%
idx = df.columns
idx
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
label = df.columns[0]
label
# Out:
# 'cgpa'

# %%
p = df.columns.tolist()       #list of column labels
p
# Out:
# ['cgpa', 'resume_score', 'placed']

# %%
q = df.columns.values   # array of column labels
q
# Out:
# array(['cgpa', 'resume_score', 'placed'], dtype=object)

# %%
p = df.rename(columns = {'cgpa' : 'updated_cgpa',
                         'resume_score' : 'semester_marks'})
p
# Out:
#     updated_cgpa  semester_marks  placed
# 0             16              11       7
# 1             14              10       6
# 2             16              13       7
# 3             14              12       7
# 4             15              12       7
# ..           ...             ...     ...
# 95            14              11       6
# 96            16              12       7
# 97            14              12       6
# 98            16              10       7
# 99            14              11       6
#
# [100 rows x 3 columns]

# %%
df['Cgpan'] = df['cgpa'].astype(int)
df
# Out:
#     cgpa  resume_score  placed  Cgpan
# 0     16            11       7     16
# 1     14            10       6     14
# 2     16            13       7     16
# 3     14            12       7     14
# 4     15            12       7     15
# ..   ...           ...     ...    ...
# 95    14            11       6     14
# 96    16            12       7     16
# 97    14            12       6     14
# 98    16            10       7     16
# 99    14            11       6     14
#
# [100 rows x 4 columns]

# %%
a = df.drop(columns = ['Cgpan', 'placed'])
a
# Out:
#     cgpa  resume_score
# 0     16            11
# 1     14            10
# 2     16            13
# 3     14            12
# 4     15            12
# ..   ...           ...
# 95    14            11
# 96    16            12
# 97    14            12
# 98    16            10
# 99    14            11
#
# [100 rows x 2 columns]

# %%
df['New'] = df['cgpa'].where(df['cgpa']>15 , other = 0)

# %%
df.sample(8)
# Out:
#     cgpa  resume_score  placed  Cgpan  New
# 15    16            10       7     16   16
# 83    15            13       7     15    0
# 3     14            12       7     14    0
# 80    15            12       7     15    0
# 67    14            11       7     14    0
# 82    15            11       7     15    0
# 69    16            14       7     16   16
# 18    13            10       6     13    0

# %%
# df merging and concatination

# %%
data1 = {
    "name" : ["sally", "marry", "john"],
    "age" : [50, 40, 30]
}

data2 = {
    "name" : ["sally", "peter", "micky"],
    "age" : [77, 44, 22]
}
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
newdf = df1.merge(df2, how = 'right')
newdf
# Out:
#     name  age
# 0  sally   77
# 1  peter   44
# 2  micky   22

# %%
newdf = df1.merge(df2, how = 'left')
newdf
# Out:
#     name  age
# 0  sally   50
# 1  marry   40
# 2   john   30

# %%
# Define a dictionary containing employee data
data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}

# Define a dictionary containing employee data
data2 = {'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Btech', 'B.A', 'B.Com', 'B.Hons']}

# %%
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
df1
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd

# %%
df2
# Out:
#      Name  Age    Address Qualification
# 0    Abhi   17     Nagpur         Btech
# 1  Ayushi   14     Kanpur           B.A
# 2  Dhiraj   12  Allahabad         B.Com
# 3  Hitesh   52    Kannuaj        B.Hons

# %%
new_df = pd.concat([df1, df2])
new_df
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
# 0    Abhi   17     Nagpur         Btech
# 1  Ayushi   14     Kanpur           B.A
# 2  Dhiraj   12  Allahabad         B.Com
# 3  Hitesh   52    Kannuaj        B.Hons

# %%
df = pd.merge(df1,df2, on = "Address", how  = "inner")
df
# Out:
#    Name_x  Age_x    Address Qualification_x  Name_y  Age_y Qualification_y
# 0     Jai     27     Nagpur             Msc    Abhi     17           Btech
# 1  Princi     24     Kanpur              MA  Ayushi     14             B.A
# 2  Gaurav     22  Allahabad             MCA  Dhiraj     12           B.Com
# 3    Anuj     32    Kannuaj             Phd  Hitesh     52          B.Hons
