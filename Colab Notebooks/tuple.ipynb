# %%
# Tuple in python  ---->

# (1). Identification = ()
# (2). Immutable data type ---> We cannot change or update the values at a runtime .
# (3). This is a container in which we can store different-different types of elements.
# (4). Indexing start from 0 and length start from 1 .

# %%
a = ('sam' , 45 , 'raj' , 78.48)
type(a)
# Out:
# tuple

# %%
### Indrexing and slicing
print(a[0])   ### forward Indexing
print(a[1])
print(a[2])
print(a[3])
print("------")
print(a[-1])   ### Backward Indexing
print(a[-2])
print(a[-3])
# Out:
# sam
# 45
# raj
# 78.48
# ------
# 78.48
# raj
# 45

# %%
print(a[1:3])
# Out:
# (45, 'raj')

# %%
a = 56
print(type(a))
a = 56,
print(type(a))
# Out:
# <class 'int'>
# <class 'tuple'>

# %%
# Imuutable data type
a = ('sam' , 45 , 'raj' , 78.48)
print(a)
# a[1] = 900
b = list(a)
print(b)
b[1] = 9000
print(b)
c = tuple(b)
print(c)
# Out:
# ('sam', 45, 'raj', 78.48)
# ['sam', 45, 'raj', 78.48]
# ['sam', 9000, 'raj', 78.48]
# ('sam', 9000, 'raj', 78.48)

# %%
a = (1,2,3)   ### Concatenation
b = (4,5,6)
c = a + b
c
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
# (2). Replication
a = (1,2,3)
a*3
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %% [markdown]
# # FUNCTIONS IN TUPLE

# %%
# (1). len() ----> It will return length of a tuple .
a = ('sam' , 45 , 'raj' , 78.48)
len(a)
# Out:
# 4

# %%
# (2). index() ----> It will return indexing of an element .
a = ('sam' , 45 , 'raj' , 78.48)
a.index(45)
# Out:
# 1

# %%
# (3). count() ----> It will return frequency of element .
a = ('sam' , 45 , 'raj' , 78.48 , 45 , 45)
a.count(45)
# Out:
# 3

# %%
# (4). min() ---> It will return  minimum value of a tuple .
a = (1,2,3)
min(a)
# Out:
# 1

# %%
# (5). max() ----> It will return maximum value of a tuple .
a = (1,2,3)
max(a)
# Out:
# 3

# %% [markdown]
# # Q.1 How can we create a user-defined tuple ?

# %%
a = []
size = int(input("Enter size:"))
for i in range(size):
    val = input("Enter item:")
    a.append(val)
# print(a)
b = tuple(a)
print(b)
# Out:
# Enter size:4
# Enter item:1
# Enter item:
# Enter item:3
# Enter item:4
# ('1', '', '3', '4')

# %% [markdown]
# # Q.2 Create a user-defined tuple in which user can add or delete an item .

# %%
a = []
size = int(input("Enter size:"))
for i in range(size):
    val = input("Enter item:")
    a.append(val)
# print(a)
b = tuple(a)
print(b)
c = input("Which item you want to delete::")
d = list(b)
# print(d)
d.remove(c)
# print(d)
e = tuple(d)
print(e)
# Out:
# Enter size:4
# Enter item:a
# Enter item:b
# Enter item:c
# Enter item:d
# ('a', 'b', 'c', 'd')
# Which item you want to delete::b
# ('a', 'c', 'd')

# %%
a = ['sam' , 'gorav' , 'aniket' , 'lokesh']
print(a)
size = int(input("how many elements you want to delete:"))
for i in range(size):
    val = input("Which item you want to delete:")
    a.remove(val)
print(a)
# Out:
# ['sam', 'gorav', 'aniket', 'lokesh']
# how many elements you want to delete:2
# Which item you want to delete:sam
# Which item you want to delete:aniket
# ['gorav', 'lokesh']

# %%
# using another list which contains items you want to delete from the list a

a = ['sam' , 'gorav' , 'aniket' , 'lokesh']
print(a)
del_items=[]
size = int(input("how many elements you want to delete:"))
for i in range(size):
    val = input("Which item you want to delete:")
    del_items.append(val)
for j in del_items:
    a.remove(j)
print(a)
# print(del_items)
# Out:
# ['sam', 'gorav', 'aniket', 'lokesh']
# how many elements you want to delete:2
# Which item you want to delete:sam
# Which item you want to delete:aniket
# ['gorav', 'lokesh']
# ['sam', 'aniket']

# %%
# using another list which contains items you want to delete from the tuple a

a = ('sam' , 'gorav' , 'aniket' , 'lokesh')
print(a)
a = list(a)
# print(a)
del_items=[]
size = int(input("how many elements you want to delete:"))
for i in range(size):
    val = input("Which item you want to delete:")
    del_items.append(val)
for j in del_items:
    a.remove(j)
# print(a)
a = tuple(a)
print(a)
# print(del_items)
# Out:
# ('sam', 'gorav', 'aniket', 'lokesh')
# how many elements you want to delete:2
# Which item you want to delete:sam
# Which item you want to delete:aniket
# ('gorav', 'lokesh')

# %%
b = ('sam' , 'gorav' , 'aniket' , 'lokesh')
print(b)
a = ['sam' , 'gorav' , 'aniket' , 'lokesh']
# print(a)
size = int(input("how many elements you want to delete:"))
for i in range(size):
    val = input("Which item you want to delete:")
    a.remove(val)
# print(a)
c = tuple(a)
print(c)
# Out:
# ('sam', 'gorav', 'aniket', 'lokesh')
# how many elements you want to delete:2
# Which item you want to delete:sam
# Which item you want to delete:aniket
# ('gorav', 'lokesh')

# %%
# add elements in a tuple

b = ('sam' , 'gorav' , 'aniket' , 'lokesh')
print(b)
a = ['sam' , 'gorav' , 'aniket' , 'lokesh']
# print(a)
size = int(input("how many elements you want to add:"))
for i in range(size):
    val = input("Which item you want to add:")
    a.append(val)
# print(a)
c = tuple(a)
print(c)
# Out:
# ('sam', 'gorav', 'aniket', 'lokesh')
# how many elements you want to add:2
# Which item you want to add:ram
# Which item you want to add:dev
# ('sam', 'gorav', 'aniket', 'lokesh', 'ram', 'dev')

# %%
# using another list which contains items you want to add to the tuple a

a = ('sam' , 'gorav' , 'aniket' , 'lokesh')
print(a)
a = list(a)
# print(a)
add_items=[]
size = int(input("How many elements you want to add:"))

for i in range(size):
    val = input("Which item you want to add:")
    add_items.append(val)

for j in add_items:
    a.append(j)
# print(a)
a = tuple(a)
print(a)
# print(del_items)
# Out:
# ('sam', 'gorav', 'aniket', 'lokesh')
# how many elements you want to add:2
# Which item you want to add:ram
# Which item you want to add:dev
# ('sam', 'gorav', 'aniket', 'lokesh', 'ram', 'dev')
